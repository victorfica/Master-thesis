# %%
import pandas as pd
from pathlib import Path
from scipy import stats

from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import learning_curve,RepeatedKFold

from sklearn.pipeline import make_pipeline
from yellowbrick.model_selection import LearningCurve
from yellowbrick.regressor import ResidualsPlot
from yellowbrick.regressor import PredictionError
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn import metrics
from sklearn.externals import joblib
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from imblearn import over_sampling as ovs
from sklearn.compose import TransformedTargetRegressor
from sklearn.preprocessing import QuantileTransformer,quantile_transform,PowerTransformer

# %matplotlib inline

# %%
sns.set_context(context="paper")
def learn_curves(estimator, features, target, cv):
    train_sizes, train_scores, validation_scores = learning_curve(
                                                 estimator, features, target,train_sizes = np.linspace(.1, 1.0, 10),
                                                 cv = cv, scoring = 'r2',n_jobs=-1)
    train_scores_mean = train_scores.mean(axis = 1)
    validation_scores_mean = validation_scores.mean(axis = 1)
    
    plt.plot(train_sizes, np.sqrt(train_scores_mean), label = 'Training error')
    plt.plot(train_sizes, np.sqrt(validation_scores_mean), label = 'Validation error')

    plt.ylabel('R2', fontsize = 14)
    plt.xlabel('Training set size', fontsize = 14)
    title = 'Learning curve'
    plt.title(title, fontsize = 18, y = 1.03)
    plt.legend()
    plt.ylim(-1,3)

# %%
#dataframe final
df_final = pd.read_csv("../data/DF_train400_skempiAB_modeller_final.csv",index_col=0)

#drop_ddg = (df_final.ddG_exp.abs() > 4.3)
#df_final = df_final.loc[-drop_ddg]


pdb_names = df_final.index
features_names = df_final.drop('ddG_exp',axis=1).columns

# %%
import math
def deltaG_to_Kd(delg):
    Kd_value = math.exp((delg*1000)/(1.98*298.15))
    return Kd_value

# %%
X = df_final.drop('ddG_exp',axis=1).astype(float)
y = df_final['ddG_exp']

# %%
# binned split
bins = np.linspace(0, len(X), 200)
y_binned = np.digitize(y, bins)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y_binned,random_state=1)

# %%
#sns.distplot( y_test , fit=stats.laplace,color="red", label="ddG_exp_test")
sns.distplot( y_train , fit=stats.nct,color="skyblue", label="ddG_exp_train")
# Out:
# /Users/vfica/miniconda3/envs/bio/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:2316: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu

# %%
import numpy as np

from yellowbrick.model_selection import ValidationCurve

#1)
selector = VarianceThreshold()

#2)
rf_model = RandomForestRegressor(random_state=1212,n_estimators=100)
#3) Crear pipeline


pipeline1 = make_pipeline(selector,rf_model)

#regr_trans = TransformedTargetRegressor(
#    regressor=pipeline1, transformer=PowerTransformer())

cv = RepeatedKFold(n_splits=5,n_repeats=2,random_state=13)

# Extract the instances and target
viz = ValidationCurve(
    pipeline1, njobs=-1,param_name="randomforestregressor__n_estimators",
    param_range=[10,30,50,100,300], cv=cv, scoring="r2")
#plt.ylim(0,0.6)
# Fit and poof the visualizer
viz.fit(X_train, y_train)
viz.poof()

# %%
#1)
selector = VarianceThreshold()
#2)
rf_model = RandomForestRegressor()
#3) Crear pipeline


pipeline1 = make_pipeline(selector,rf_model)
# grid params
param_grid = {
    'randomforestregressor__bootstrap': [True],
    'randomforestregressor__max_depth': [22],
    'randomforestregressor__max_features': ['sqrt'],
    'randomforestregressor__max_leaf_nodes':[None],
    'randomforestregressor__min_samples_leaf': [9],
    'randomforestregressor__min_samples_split': [15],
    'randomforestregressor__n_estimators': [100],
    'randomforestregressor__random_state':[1212],
    'variancethreshold__threshold':[0.] }

cv = RepeatedKFold(n_splits=5,n_repeats=10,random_state=13)

# Instantiate the grid search model
grid1 = GridSearchCV(pipeline1, param_grid, verbose=5, n_jobs=-1,cv=cv,scoring=['neg_mean_squared_error','r2'],
                        refit='r2',return_train_score=True)

grid1.fit(X_train,y_train)
# Out:
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  50 | elapsed:    2.1s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  41 out of  50 | elapsed:    2.5s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    2.7s finished
# GridSearchCV(cv=<sklearn.model_selection._split.RepeatedKFold object at 0x1a2a265128>,
#        error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('variancethreshold', VarianceThreshold(threshold=0.0)), ('randomforestregressor', RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurit...='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False))]),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'randomforestregressor__bootstrap': [True], 'randomforestregressor__max_depth': [22], 'randomforestregressor__max_features': ['sqrt'], 'randomforestregressor__max_leaf_nodes': [None], 'randomforestregressor__min_samples_leaf': [9], 'randomforestregressor__min_samples_split': [20], 'randomforestregressor__n_estimators': [100], 'randomforestregressor__random_state': [1212], 'variancethreshold__threshold': [0.0]},
#        pre_dispatch='2*n_jobs', refit='r2', return_train_score=True,
#        scoring=['neg_mean_squared_error', 'r2'], verbose=5)

# %%
# index of best scores
rmse_bestCV_test_index = grid1.cv_results_['mean_test_neg_mean_squared_error'].argmax()
rmse_bestCV_train_index = grid1.cv_results_['mean_train_neg_mean_squared_error'].argmax()
r2_bestCV_test_index = grid1.cv_results_['mean_test_r2'].argmax()
r2_bestCV_train_index = grid1.cv_results_['mean_train_r2'].argmax()
# scores
rmse_bestCV_test_score = grid1.cv_results_['mean_test_neg_mean_squared_error'][rmse_bestCV_test_index]
rmse_bestCV_test_std = grid1.cv_results_['std_test_neg_mean_squared_error'][rmse_bestCV_test_index]
rmse_bestCV_train_score = grid1.cv_results_['mean_train_neg_mean_squared_error'][rmse_bestCV_train_index]
rmse_bestCV_train_std = grid1.cv_results_['std_train_neg_mean_squared_error'][rmse_bestCV_train_index]

r2_bestCV_test_score = grid1.cv_results_['mean_test_r2'][r2_bestCV_test_index]
r2_bestCV_test_std = grid1.cv_results_['std_test_r2'][r2_bestCV_test_index]
r2_bestCV_train_score = grid1.cv_results_['mean_train_r2'][r2_bestCV_train_index]
r2_bestCV_train_std = grid1.cv_results_['std_train_r2'][r2_bestCV_train_index]

print('CV test RMSE {:f} +/- {:f}'.format(np.sqrt(-rmse_bestCV_test_score),np.sqrt(rmse_bestCV_test_std)))
print('CV train RMSE {:f} +/- {:f}'.format(np.sqrt(-rmse_bestCV_train_score),np.sqrt(rmse_bestCV_train_std)))
print('CV test r2 {:f} +/- {:f}'.format(r2_bestCV_test_score,r2_bestCV_test_std))
print('CV train r2 {:f} +/- {:f}'.format(r2_bestCV_train_score,r2_bestCV_train_std))

print(r2_bestCV_train_score-r2_bestCV_test_score)
print("",grid1.best_params_)
y_test_pred = grid1.best_estimator_.predict(X_test)
y_train_pred = grid1.best_estimator_.predict(X_train)
print("\nRMSE for test dataset: {}".format(np.round(np.sqrt(mean_squared_error(y_test, y_test_pred)), 2)))
print("RMSE for train dataset: {}".format(np.round(np.sqrt(mean_squared_error(y_train, y_train_pred)), 2)))
print("pearson corr  {:f}".format(np.corrcoef(y_test_pred,y_test)[0][1]))
print('R2 test',r2_score(y_test,y_test_pred))
print('R2 train',r2_score(y_train,y_train_pred))
# Out:
# CV test RMSE 1.700881 +/- 0.573278
# CV train RMSE 1.449413 +/- 0.254178
# CV test r2 0.188215 +/- 0.029969
# CV train r2 0.412674 +/- 0.009303
# 0.2244595344687174
#  {'randomforestregressor__bootstrap': True, 'randomforestregressor__max_depth': 22, 'randomforestregressor__max_features': 'sqrt', 'randomforestregressor__max_leaf_nodes': None, 'randomforestregressor__min_samples_leaf': 9, 'randomforestregressor__min_samples_split': 20, 'randomforestregressor__n_estimators': 100, 'randomforestregressor__random_state': 1212, 'variancethreshold__threshold': 0.0}
#
# RMSE for test dataset: 1.75
# RMSE for train dataset: 1.43
# pearson corr  0.476416
# R2 test 0.1835554726033618
# R2 train 0.4283393173867648

# %%
# Out:
# 0.300056355076

# %%
{'randomforestregressor__bootstrap': True, 'randomforestregressor__max_depth': 8,
 'randomforestregressor__max_features': 'sqrt', 'randomforestregressor__max_leaf_nodes': None,
 'randomforestregressor__min_samples_leaf': 13, 'randomforestregressor__min_samples_split': 11,
 'randomforestregressor__n_estimators': 100, 'randomforestregressor__random_state': 1212,
 'variancethreshold__threshold': 0.0}

# %%
visualizer = ResidualsPlot(grid1.best_estimator_)

visualizer.fit(X_train, y_train)  # Fit the training data to the model
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.poof()                 # Draw/show/poof the data

# %%
perror = PredictionError(grid1.best_estimator_)

perror.fit(X_train, y_train)  # Fit the training data to the visualizer
perror.score(X_test, y_test)  # Evaluate the model on the test data
g = perror.poof()

# %%
viz = LearningCurve(grid1.best_estimator_, cv=cv, n_jobs=-1,scoring='r2',train_sizes=np.linspace(0.2, 1.0, 10))
viz.fit(X, y)
#plt.ylim(0,-4)
viz.poof()

# %%
final_rf = grid1.best_estimator_.fit(X,y)

# %%
# save final model

joblib.dump(final_rf, 'RFmodel_train15skempiAB_FINAL.pkl')
# Out:
# ['RFmodel_train15skempiAB_FINAL.pkl']

# %%
g

# %%
rmse_test = np.round(np.sqrt(mean_squared_error(y_test, y_test_pred)), 3)
df_pred = pd.DataFrame({"Predicted ddG(kcal/mol)": y_test_pred, "Actual ddG(kcal/mol)": y_test.values})
pearsonr_test = round(df_pred.corr().iloc[0,1],3)

g = sns.regplot(x="Actual ddG(kcal/mol)", y="Predicted ddG(kcal/mol)",data=df_pred)
plt.title("Predicted vs Experimental ddG (Independent set: 123 complexes)")

plt.text(-2,3,"pearsonr = %s" %pearsonr_test)
plt.text(4.5,-0.5,"RMSE = %s" %rmse_test)

#plt.savefig("RFmodel_300_testfit.png",dpi=600)
# Out:
# Text(4.5, -0.5, 'RMSE = 0.755')

# %%
df_train_pred = pd.DataFrame({"Predicted ddG(kcal/mol)": y_train, "Actual ddG(kcal/mol)": y_train_pred})
pearsonr_train = round(df_train_pred.corr().iloc[0,1],3)
rmse_train = np.round(np.sqrt(mean_squared_error(y_train, y_train_pred)), 3)

g = sns.regplot(x="Actual ddG(kcal/mol)", y="Predicted ddG(kcal/mol)",data=df_train_pred)

plt.text(-0.4,6.5,"pearsonr = %s" %pearsonr_train)
plt.text(3.5,-2.5,"RMSE = %s" %rmse_train)
plt.title("Predicted vs Experimental ddG (Train set: 492 complexes)")
#plt.savefig("RFmodel_300_trainfit.png",dpi=600)
# Out:
# Text(0.5, 1.0, 'Predicted vs Experimental ddG (Train set: 492 complexes)')

# %%
rf_model = grid1.best_estimator_.named_steps["randomforestregressor"]
importances = list(rf_model.feature_importances_)
feature_list = df_final.columns
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 4)) for feature, importance in zip(feature_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances]
# Out:
# Variable: V_V_change           Importance: 0.0781
# Variable: V_S_change           Importance: 0.0673
# Variable: V_W_change           Importance: 0.0401
# Variable: T_M_change           Importance: 0.04
# Variable: V_P_change           Importance: 0.0321
# Variable: Y_T_change           Importance: 0.0308
# Variable: Y_Y_change           Importance: 0.0283
# Variable: V_R_change           Importance: 0.0239
# Variable: intraclashes_energy_1_change Importance: 0.0236
# Variable: W_F_change           Importance: 0.0225
# Variable: V_M_change           Importance: 0.0221
# Variable: V_Q_change           Importance: 0.0206
# Variable: Y_I_change           Importance: 0.0203
# Variable: W_I_change           Importance: 0.0196
# Variable: W_S_change           Importance: 0.0185
# Variable: V_Y_change           Importance: 0.0178
# Variable: intraclashes_energy_2_change Importance: 0.0176
# Variable: W_E_change           Importance: 0.0174
# Variable: V_T_change           Importance: 0.0155
# Variable: Y_H_change           Importance: 0.015
# Variable: W_Y_change           Importance: 0.0148
# Variable: W_A_change           Importance: 0.014
# Variable: W_W_change           Importance: 0.0138
# Variable: Y_V_change           Importance: 0.0136
# Variable: W_R_change           Importance: 0.0133
# Variable: Y_F_change           Importance: 0.0127
# Variable: W_V_change           Importance: 0.0126
# Variable: Y_W_change           Importance: 0.0126
# Variable: T_W_change           Importance: 0.0123
# Variable: S_W_change           Importance: 0.0122
# Variable: Y_M_change           Importance: 0.0113
# Variable: Y_C_change           Importance: 0.0111
# Variable: Y_D_change           Importance: 0.011
# Variable: V_N_change           Importance: 0.0106
# Variable: W_C_change           Importance: 0.0103
# Variable: W_Q_change           Importance: 0.0103
# Variable: Y_N_change           Importance: 0.0102
# Variable: W_T_change           Importance: 0.0096
# Variable: W_K_change           Importance: 0.0094
# Variable: Y_E_change           Importance: 0.0094
# Variable: Y_A_change           Importance: 0.0092
# Variable: D_C_change           Importance: 0.0089
# Variable: T_P_change           Importance: 0.0085
# Variable: Y_P_change           Importance: 0.0083
# Variable: V_C_change           Importance: 0.0073
# Variable: V_L_change           Importance: 0.007
# Variable: V_E_change           Importance: 0.0063
# Variable: V_G_change           Importance: 0.0062
# Variable: A_Y_change           Importance: 0.0056
# Variable: Y_K_change           Importance: 0.0056
# Variable: V_F_change           Importance: 0.0049
# Variable: P_T_change           Importance: 0.0048
# Variable: L_S_change           Importance: 0.0046
# Variable: M_A_change           Importance: 0.0044
# Variable: Q_R_change           Importance: 0.004
# Variable: V_H_change           Importance: 0.004
# Variable: V_K_change           Importance: 0.004
# Variable: W_G_change           Importance: 0.004
# Variable: Q_A_change           Importance: 0.0037
# Variable: P_V_change           Importance: 0.0036
# Variable: W_L_change           Importance: 0.0034
# Variable: T_Y_change           Importance: 0.0028
# Variable: T_L_change           Importance: 0.0027
# Variable: T_S_change           Importance: 0.0027
# Variable: H_Q_change           Importance: 0.0025
# Variable: Y_Q_change           Importance: 0.0023
# Variable: T_C_change           Importance: 0.0022
# Variable: Y_S_change           Importance: 0.0022
# Variable: L_T_change           Importance: 0.0019
# Variable: N_Y_change           Importance: 0.0019
# Variable: C_M_change           Importance: 0.0017
# Variable: A_G_change           Importance: 0.0016
# Variable: L_L_change           Importance: 0.0016
# Variable: L_V_change           Importance: 0.0016
# Variable: P_K_change           Importance: 0.0016
# Variable: Q_S_change           Importance: 0.0016
# Variable: T_F_change           Importance: 0.0016
# Variable: T_Q_change           Importance: 0.0015
# Variable: A_S_change           Importance: 0.0014
# Variable: C_V_change           Importance: 0.0014
# Variable: I_N_change           Importance: 0.0014
# Variable: C_Q_change           Importance: 0.0013
# Variable: C_N_change           Importance: 0.0012
# Variable: Q_G_change           Importance: 0.0012
# Variable: Q_L_change           Importance: 0.0012
# Variable: Q_W_change           Importance: 0.0012
# Variable: R_I_change           Importance: 0.0012
# Variable: S_M_change           Importance: 0.0012
# Variable: V_I_change           Importance: 0.0012
# Variable: N_N_change           Importance: 0.0011
# Variable: P_Y_change           Importance: 0.001
# Variable: C_D_change           Importance: 0.0009
# Variable: L_F_change           Importance: 0.0009
# Variable: G_M_change           Importance: 0.0008
# Variable: I_M_change           Importance: 0.0008
# Variable: N_K_change           Importance: 0.0008
# Variable: N_Q_change           Importance: 0.0008
# Variable: T_R_change           Importance: 0.0008
# Variable: A_N_change           Importance: 0.0007
# Variable: C_H_change           Importance: 0.0007
# Variable: F_L_change           Importance: 0.0007
# Variable: N_M_change           Importance: 0.0007
# Variable: P_S_change           Importance: 0.0007
# Variable: W_P_change           Importance: 0.0007
# Variable: C_T_change           Importance: 0.0006
# Variable: D_P_change           Importance: 0.0006
# Variable: L_E_change           Importance: 0.0006
# Variable: M_Y_change           Importance: 0.0006
# Variable: Q_M_change           Importance: 0.0006
# Variable: A_Q_change           Importance: 0.0005
# Variable: L_I_change           Importance: 0.0005
# Variable: P_W_change           Importance: 0.0005
# Variable: T_G_change           Importance: 0.0005
# Variable: T_V_change           Importance: 0.0005
# Variable: W_D_change           Importance: 0.0005
# Variable: W_M_change           Importance: 0.0005
# Variable: L_H_change           Importance: 0.0004
# Variable: L_P_change           Importance: 0.0004
# Variable: V_D_change           Importance: 0.0004
# Variable: W_N_change           Importance: 0.0004
# Variable: A_D_change           Importance: 0.0003
# Variable: C_G_change           Importance: 0.0003
# Variable: E_S_change           Importance: 0.0003
# Variable: F_R_change           Importance: 0.0003
# Variable: F_W_change           Importance: 0.0003
# Variable: F_Y_change           Importance: 0.0003
# Variable: H_K_change           Importance: 0.0003
# Variable: H_S_change           Importance: 0.0003
# Variable: L_C_change           Importance: 0.0003
# Variable: P_A_change           Importance: 0.0003
# Variable: P_Q_change           Importance: 0.0003
# Variable: Q_D_change           Importance: 0.0003
# Variable: R_K_change           Importance: 0.0003
# Variable: T_T_change           Importance: 0.0003
# Variable: F_Q_change           Importance: 0.0002
# Variable: G_A_change           Importance: 0.0002
# Variable: I_E_change           Importance: 0.0002
# Variable: K_K_change           Importance: 0.0002
# Variable: S_S_change           Importance: 0.0002
# Variable: T_E_change           Importance: 0.0002
# Variable: C_A_change           Importance: 0.0001
# Variable: E_K_change           Importance: 0.0001
# Variable: E_P_change           Importance: 0.0001
# Variable: F_F_change           Importance: 0.0001
# Variable: G_P_change           Importance: 0.0001
# Variable: H_M_change           Importance: 0.0001
# Variable: K_N_change           Importance: 0.0001
# Variable: L_R_change           Importance: 0.0001
# Variable: N_V_change           Importance: 0.0001
# Variable: P_C_change           Importance: 0.0001
# Variable: P_D_change           Importance: 0.0001
# Variable: P_G_change           Importance: 0.0001
# Variable: P_P_change           Importance: 0.0001
# Variable: Q_I_change           Importance: 0.0001
# Variable: Q_N_change           Importance: 0.0001
# Variable: R_G_change           Importance: 0.0001
# Variable: S_D_change           Importance: 0.0001
# Variable: S_P_change           Importance: 0.0001
# Variable: T_I_change           Importance: 0.0001
# Variable: Y_G_change           Importance: 0.0001
# Variable: Y_R_change           Importance: 0.0001
# Variable: A_A_change           Importance: 0.0
# Variable: A_C_change           Importance: 0.0
# Variable: A_E_change           Importance: 0.0
# Variable: A_F_change           Importance: 0.0
# Variable: A_H_change           Importance: 0.0
# Variable: A_I_change           Importance: 0.0
# Variable: A_K_change           Importance: 0.0
# Variable: A_L_change           Importance: 0.0
# Variable: A_M_change           Importance: 0.0
# Variable: A_P_change           Importance: 0.0
# Variable: A_R_change           Importance: 0.0
# Variable: A_T_change           Importance: 0.0
# Variable: A_V_change           Importance: 0.0
# Variable: A_W_change           Importance: 0.0
# Variable: C_C_change           Importance: 0.0
# Variable: C_E_change           Importance: 0.0
# Variable: C_F_change           Importance: 0.0
# Variable: C_I_change           Importance: 0.0
# Variable: C_K_change           Importance: 0.0
# Variable: C_L_change           Importance: 0.0
# Variable: C_P_change           Importance: 0.0
# Variable: C_R_change           Importance: 0.0
# Variable: C_S_change           Importance: 0.0
# Variable: C_W_change           Importance: 0.0
# Variable: C_Y_change           Importance: 0.0
# Variable: D_A_change           Importance: 0.0
# Variable: D_D_change           Importance: 0.0
# Variable: D_E_change           Importance: 0.0
# Variable: D_F_change           Importance: 0.0
# Variable: D_G_change           Importance: 0.0
# Variable: D_H_change           Importance: 0.0
# Variable: D_I_change           Importance: 0.0
# Variable: D_K_change           Importance: 0.0
# Variable: D_L_change           Importance: 0.0
# Variable: D_M_change           Importance: 0.0
# Variable: D_N_change           Importance: 0.0
# Variable: D_Q_change           Importance: 0.0
# Variable: D_R_change           Importance: 0.0
# Variable: D_S_change           Importance: 0.0
# Variable: D_T_change           Importance: 0.0
# Variable: D_V_change           Importance: 0.0
# Variable: D_W_change           Importance: 0.0
# Variable: D_Y_change           Importance: 0.0
# Variable: E_A_change           Importance: 0.0
# Variable: E_C_change           Importance: 0.0
# Variable: E_D_change           Importance: 0.0
# Variable: E_E_change           Importance: 0.0
# Variable: E_F_change           Importance: 0.0
# Variable: E_G_change           Importance: 0.0
# Variable: E_H_change           Importance: 0.0
# Variable: E_I_change           Importance: 0.0
# Variable: E_L_change           Importance: 0.0
# Variable: E_M_change           Importance: 0.0
# Variable: E_N_change           Importance: 0.0
# Variable: E_Q_change           Importance: 0.0
# Variable: E_R_change           Importance: 0.0
# Variable: E_T_change           Importance: 0.0
# Variable: E_V_change           Importance: 0.0
# Variable: E_W_change           Importance: 0.0
# Variable: E_Y_change           Importance: 0.0
# Variable: F_A_change           Importance: 0.0
# Variable: F_C_change           Importance: 0.0
# Variable: F_D_change           Importance: 0.0
# Variable: F_E_change           Importance: 0.0
# Variable: F_G_change           Importance: 0.0
# Variable: F_H_change           Importance: 0.0
# Variable: F_I_change           Importance: 0.0
# Variable: F_K_change           Importance: 0.0
# Variable: F_M_change           Importance: 0.0
# Variable: F_N_change           Importance: 0.0
# Variable: F_P_change           Importance: 0.0
# Variable: F_S_change           Importance: 0.0
# Variable: F_T_change           Importance: 0.0
# Variable: F_V_change           Importance: 0.0
# Variable: G_C_change           Importance: 0.0
# Variable: G_D_change           Importance: 0.0
# Variable: G_E_change           Importance: 0.0
# Variable: G_F_change           Importance: 0.0
# Variable: G_G_change           Importance: 0.0
# Variable: G_H_change           Importance: 0.0
# Variable: G_I_change           Importance: 0.0
# Variable: G_K_change           Importance: 0.0
# Variable: G_L_change           Importance: 0.0
# Variable: G_N_change           Importance: 0.0
# Variable: G_Q_change           Importance: 0.0
# Variable: G_R_change           Importance: 0.0
# Variable: G_S_change           Importance: 0.0
# Variable: G_T_change           Importance: 0.0
# Variable: G_V_change           Importance: 0.0
# Variable: G_W_change           Importance: 0.0
# Variable: G_Y_change           Importance: 0.0
# Variable: H_A_change           Importance: 0.0
# Variable: H_C_change           Importance: 0.0
# Variable: H_D_change           Importance: 0.0
# Variable: H_E_change           Importance: 0.0
# Variable: H_F_change           Importance: 0.0
# Variable: H_G_change           Importance: 0.0
# Variable: H_H_change           Importance: 0.0
# Variable: H_I_change           Importance: 0.0
# Variable: H_L_change           Importance: 0.0
# Variable: H_N_change           Importance: 0.0
# Variable: H_P_change           Importance: 0.0
# Variable: H_R_change           Importance: 0.0
# Variable: H_T_change           Importance: 0.0
# Variable: H_V_change           Importance: 0.0
# Variable: H_W_change           Importance: 0.0
# Variable: H_Y_change           Importance: 0.0
# Variable: I_A_change           Importance: 0.0
# Variable: I_C_change           Importance: 0.0
# Variable: I_D_change           Importance: 0.0
# Variable: I_F_change           Importance: 0.0
# Variable: I_G_change           Importance: 0.0
# Variable: I_H_change           Importance: 0.0
# Variable: I_I_change           Importance: 0.0
# Variable: I_K_change           Importance: 0.0
# Variable: I_L_change           Importance: 0.0
# Variable: I_P_change           Importance: 0.0
# Variable: I_Q_change           Importance: 0.0
# Variable: I_R_change           Importance: 0.0
# Variable: I_S_change           Importance: 0.0
# Variable: I_T_change           Importance: 0.0
# Variable: I_V_change           Importance: 0.0
# Variable: I_W_change           Importance: 0.0
# Variable: I_Y_change           Importance: 0.0
# Variable: K_A_change           Importance: 0.0
# Variable: K_C_change           Importance: 0.0
# Variable: K_D_change           Importance: 0.0
# Variable: K_E_change           Importance: 0.0
# Variable: K_F_change           Importance: 0.0
# Variable: K_G_change           Importance: 0.0
# Variable: K_H_change           Importance: 0.0
# Variable: K_I_change           Importance: 0.0
# Variable: K_L_change           Importance: 0.0
# Variable: K_M_change           Importance: 0.0
# Variable: K_P_change           Importance: 0.0
# Variable: K_Q_change           Importance: 0.0
# Variable: K_R_change           Importance: 0.0
# Variable: K_S_change           Importance: 0.0
# Variable: K_T_change           Importance: 0.0
# Variable: K_V_change           Importance: 0.0
# Variable: K_W_change           Importance: 0.0
# Variable: K_Y_change           Importance: 0.0
# Variable: L_A_change           Importance: 0.0
# Variable: L_D_change           Importance: 0.0
# Variable: L_G_change           Importance: 0.0
# Variable: L_K_change           Importance: 0.0
# Variable: L_M_change           Importance: 0.0
# Variable: L_N_change           Importance: 0.0
# Variable: L_Q_change           Importance: 0.0
# Variable: L_W_change           Importance: 0.0
# Variable: L_Y_change           Importance: 0.0
# Variable: M_C_change           Importance: 0.0
# Variable: M_D_change           Importance: 0.0
# Variable: M_E_change           Importance: 0.0
# Variable: M_F_change           Importance: 0.0
# Variable: M_G_change           Importance: 0.0
# Variable: M_H_change           Importance: 0.0
# Variable: M_I_change           Importance: 0.0
# Variable: M_K_change           Importance: 0.0
# Variable: M_L_change           Importance: 0.0
# Variable: M_M_change           Importance: 0.0
# Variable: M_N_change           Importance: 0.0
# Variable: M_P_change           Importance: 0.0
# Variable: M_Q_change           Importance: 0.0
# Variable: M_R_change           Importance: 0.0
# Variable: M_S_change           Importance: 0.0
# Variable: M_T_change           Importance: 0.0
# Variable: M_V_change           Importance: 0.0
# Variable: M_W_change           Importance: 0.0
# Variable: N_A_change           Importance: 0.0
# Variable: N_C_change           Importance: 0.0
# Variable: N_D_change           Importance: 0.0
# Variable: N_E_change           Importance: 0.0
# Variable: N_F_change           Importance: 0.0
# Variable: N_G_change           Importance: 0.0
# Variable: N_H_change           Importance: 0.0
# Variable: N_I_change           Importance: 0.0
# Variable: N_L_change           Importance: 0.0
# Variable: N_P_change           Importance: 0.0
# Variable: N_R_change           Importance: 0.0
# Variable: N_S_change           Importance: 0.0
# Variable: N_T_change           Importance: 0.0
# Variable: N_W_change           Importance: 0.0
# Variable: P_E_change           Importance: 0.0
# Variable: P_F_change           Importance: 0.0
# Variable: P_H_change           Importance: 0.0
# Variable: P_I_change           Importance: 0.0
# Variable: P_L_change           Importance: 0.0
# Variable: P_M_change           Importance: 0.0
# Variable: P_N_change           Importance: 0.0
# Variable: P_R_change           Importance: 0.0
# Variable: Q_C_change           Importance: 0.0
# Variable: Q_E_change           Importance: 0.0
# Variable: Q_F_change           Importance: 0.0
# Variable: Q_H_change           Importance: 0.0
# Variable: Q_K_change           Importance: 0.0
# Variable: Q_P_change           Importance: 0.0
# Variable: Q_Q_change           Importance: 0.0
# Variable: Q_T_change           Importance: 0.0
# Variable: Q_V_change           Importance: 0.0
# Variable: Q_Y_change           Importance: 0.0
# Variable: R_A_change           Importance: 0.0
# Variable: R_C_change           Importance: 0.0
# Variable: R_D_change           Importance: 0.0
# Variable: R_E_change           Importance: 0.0
# Variable: R_F_change           Importance: 0.0
# Variable: R_H_change           Importance: 0.0
# Variable: R_L_change           Importance: 0.0
# Variable: R_M_change           Importance: 0.0
# Variable: R_N_change           Importance: 0.0
# Variable: R_P_change           Importance: 0.0
# Variable: R_Q_change           Importance: 0.0
# Variable: R_R_change           Importance: 0.0
# Variable: R_S_change           Importance: 0.0
# Variable: R_T_change           Importance: 0.0
# Variable: R_V_change           Importance: 0.0
# Variable: R_W_change           Importance: 0.0
# Variable: R_Y_change           Importance: 0.0
# Variable: S_A_change           Importance: 0.0
# Variable: S_C_change           Importance: 0.0
# Variable: S_E_change           Importance: 0.0
# Variable: S_F_change           Importance: 0.0
# Variable: S_G_change           Importance: 0.0
# Variable: S_H_change           Importance: 0.0
# Variable: S_I_change           Importance: 0.0
# Variable: S_K_change           Importance: 0.0
# Variable: S_L_change           Importance: 0.0
# Variable: S_N_change           Importance: 0.0
# Variable: S_Q_change           Importance: 0.0
# Variable: S_R_change           Importance: 0.0
# Variable: S_T_change           Importance: 0.0
# Variable: S_V_change           Importance: 0.0
# Variable: S_Y_change           Importance: 0.0
# Variable: T_A_change           Importance: 0.0
# Variable: T_D_change           Importance: 0.0
# Variable: T_H_change           Importance: 0.0
# Variable: T_K_change           Importance: 0.0
# Variable: T_N_change           Importance: 0.0
# Variable: V_A_change           Importance: 0.0
# Variable: W_H_change           Importance: 0.0
# Variable: Y_L_change           Importance: 0.0
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
idx_features = rf_model.feature_importances_.argsort()[::-1]
plt.figure(figsize=(15,4))

plt.bar(np.arange(len(idx_features)), rf_model.feature_importances_[idx_features])
plt.xticks(range(len(feature_list)),feature_list[idx_features])
plt.autoscale(enable=True, axis='x', tight=True)
plt.xlabel(u"Feature importance")
#plt.savefig("RFmodel_300_50features",dpi=600,bbox_inches="tight")
# Out:
# Text(0.5, 0, 'Feature importance')

# %%
X_train.columns
# Out:
# Index(['A_A_change', 'A_C_change', 'A_D_change', 'A_E_change', 'A_F_change',
#        'A_G_change', 'A_H_change', 'A_I_change', 'A_K_change', 'A_L_change',
#        ...
#        'interface_residues_wt', 'interface_residues_clashing_wt',
#        'interface_residues_vdw_clashing_wt',
#        'interface_residues_bb_clashing_wt', 'if_phil', 'if_phob', 'if_total',
#        'sasa_phil', 'sasa_phob', 'sasa_total'],
#       dtype='object', length=462)

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
mir_result = mutual_info_regression(X_train, y_train) # mutual information regression feature ordering
feature_scores = []
for i in np.arange(len(X_train.columns)):
    feature_scores.append([X_train.columns[i],mir_result[i]])
sorted_scores = sorted(np.array(feature_scores), key=lambda s: float(s[1]), reverse=True) 
print(np.array(sorted_scores))
# Out:
# [['sasa_total' '0.2979233285437628']
#  ['sasa_phob' '0.27298908594410864']
#  ['if_phob' '0.2528461619509059']
#  ['sasa_phil' '0.25241377964700185']
#  ['intraclashes_energy_1_wt' '0.24516924344710977']
#  ['if_total' '0.24099690761270942']
#  ['intraclashes_energy_2_wt' '0.2134597519352508']
#  ['if_phil' '0.20399867433047447']
#  ['torsional_clash_wt' '0.19370651915529935']
#  ['backbone_hbond_wt' '0.19305293436143867']
#  ['backbone_clash_wt' '0.18452598792196184']
#  ['energy_ionisation_wt' '0.18195115208624735']
#  ['dg_wt' '0.1712641392841343']
#  ['disulfide_wt' '0.171229040263023']
#  ['sidechain_hbond_wt' '0.16972252793884035']
#  ['van_der_waals_wt' '0.15204983848546316']
#  ['interface_residues_wt' '0.14820928285870938']
#  ['van_der_waals_clashes_wt' '0.14795137820246484']
#  ['electrostatic_kon_wt' '0.14650096364470588']
#  ['entropy_mainchain_wt' '0.14575005316133227']
#  ['electrostatics_wt' '0.14460221401274387']
#  ['entropy_sidechain_wt' '0.13577952810257043']
#  ['van_der_waals_change' '0.12593028933104966']
#  ['solvation_hydrophobic_wt' '0.12080467636114145']
#  ['solvation_polar_wt' '0.11456936758135061']
#  ['solvation_polar_change' '0.11194948676611727']
#  ['sidechain_hbond_change' '0.11008560022938552']
#  ['torsional_clash_change' '0.09896690287362375']
#  ['backbone_hbond_change' '0.08404887616381407']
#  ['intraclashes_energy_1_change' '0.07766515700853471']
#  ['dg_change' '0.07743922795871061']
#  ['backbone_clash_change' '0.07322262840147697']
#  ['entropy_sidechain_change' '0.06400377522229261']
#  ['N_R_change' '0.05445589597397249']
#  ['electrostatics_change' '0.052385944700724885']
#  ['Y_S_change' '0.052332679700195506']
#  ['helix_dipole_wt' '0.05137826801528966']
#  ['van_der_waals_clashes_change' '0.0495497517846446']
#  ['solvation_hydrophobic_change' '0.04643837107166693']
#  ['S_F_change' '0.04562757730206024']
#  ['Y_A_change' '0.0453257197560637']
#  ['R_E_change' '0.044176056581456846']
#  ['Y_N_change' '0.04270115711956346']
#  ['interface_residues_bb_clashing_wt' '0.041647176729006974']
#  ['Y_D_change' '0.03878647539461544']
#  ['E_N_change' '0.03495563387158618']
#  ['cis_bond_wt' '0.03470920608207395']
#  ['helix_dipole_change' '0.033676509451070036']
#  ['N_Y_change' '0.031990511599828686']
#  ['Y_L_change' '0.029085163277932313']
#  ['F_N_change' '0.028855147492069078']
#  ['intraclashes_energy_2_change' '0.028585961697708218']
#  ['D_L_change' '0.027562928015463672']
#  ['Y_W_change' '0.026971061461594115']
#  ['K_W_change' '0.02661421746414372']
#  ['Q_R_change' '0.02551786202979822']
#  ['A_N_change' '0.025145424310563103']
#  ['energy_ionisation_change' '0.024867821721448635']
#  ['S_S_change' '0.024262993725065796']
#  ['F_T_change' '0.022338074671870878']
#  ['interface_residues_clashing_wt' '0.022229330342356635']
#  ['G_Y_change' '0.021893967255806945']
#  ['S_E_change' '0.021059394087064254']
#  ['G_I_change' '0.01997476219901495']
#  ['S_Y_change' '0.01988795741639282']
#  ['D_N_change' '0.019497399974422347']
#  ['K_A_change' '0.019373128995851863']
#  ['R_G_change' '0.018172731650083263']
#  ['Y_T_change' '0.018157989817483733']
#  ['R_N_change' '0.018126059293852137']
#  ['interface_residues_change' '0.017790146114951444']
#  ['I_R_change' '0.017359806211238116']
#  ['R_Q_change' '0.01719610455725684']
#  ['Y_R_change' '0.017019698655995175']
#  ['D_F_change' '0.016569298788291498']
#  ['Q_Q_change' '0.015986258532120656']
#  ['M_E_change' '0.015510191560555775']
#  ['T_W_change' '0.01550078162100288']
#  ['M_W_change' '0.015212683123731141']
#  ['A_Y_change' '0.015149587505847606']
#  ['K_F_change' '0.014626432544545764']
#  ['C_Y_change' '0.014394280710890994']
#  ['H_E_change' '0.014229530025711812']
#  ['Y_H_change' '0.013912268157450836']
#  ['L_M_change' '0.013208999983995717']
#  ['F_P_change' '0.013155226317376423']
#  ['K_I_change' '0.013097621779688984']
#  ['L_N_change' '0.01302943846600546']
#  ['cis_bond_change' '0.012913588381184837']
#  ['Y_Y_change' '0.012867238179766538']
#  ['W_Y_change' '0.012723481690081417']
#  ['P_Y_change' '0.012715743346465525']
#  ['R_A_change' '0.01270411711606112']
#  ['K_D_change' '0.012599626081563065']
#  ['N_E_change' '0.012599510373140665']
#  ['V_G_change' '0.012525422303193867']
#  ['F_R_change' '0.012515623712908042']
#  ['P_S_change' '0.012425320615160551']
#  ['D_S_change' '0.012061336055030791']
#  ['L_E_change' '0.012012703407157543']
#  ['E_L_change' '0.01193891313750517']
#  ['C_I_change' '0.011805514555993213']
#  ['C_R_change' '0.011758492661910314']
#  ['T_E_change' '0.011716202195186654']
#  ['A_R_change' '0.011660799528363741']
#  ['G_N_change' '0.011622631511914117']
#  ['K_G_change' '0.011555178193457083']
#  ['P_I_change' '0.011503320051699628']
#  ['A_Q_change' '0.011385696061541717']
#  ['interface_residues_clashing_change' '0.011312587311760769']
#  ['W_K_change' '0.01118705526791941']
#  ['H_R_change' '0.010965215645721615']
#  ['L_G_change' '0.010921496408629716']
#  ['S_R_change' '0.010796268662760289']
#  ['F_Q_change' '0.010773244161669249']
#  ['C_P_change' '0.010665500190986998']
#  ['R_P_change' '0.010645932356361909']
#  ['H_D_change' '0.010602711431014988']
#  ['W_T_change' '0.01059147220579404']
#  ['C_F_change' '0.010416920954068098']
#  ['V_T_change' '0.010338833046577456']
#  ['S_K_change' '0.010335262356023556']
#  ['G_K_change' '0.010222949555365402']
#  ['Y_P_change' '0.009813845007887734']
#  ['G_S_change' '0.009676281819461785']
#  ['K_V_change' '0.009484985605701546']
#  ['V_Q_change' '0.00941922835904907']
#  ['N_D_change' '0.009321717906374927']
#  ['H_A_change' '0.009023130801320223']
#  ['S_Q_change' '0.008917260523365833']
#  ['partial_covalent_bonds_wt' '0.008629030987108877']
#  ['E_H_change' '0.008617086318224887']
#  ['R_Y_change' '0.008426645307769931']
#  ['A_T_change' '0.008415202279481448']
#  ['K_M_change' '0.008400791328281088']
#  ['K_Q_change' '0.008393210619581204']
#  ['E_E_change' '0.008083009484862957']
#  ['T_M_change' '0.008071036474413207']
#  ['H_F_change' '0.00801524392341757']
#  ['D_D_change' '0.007743992682420542']
#  ['D_Y_change' '0.007635385426373986']
#  ['A_C_change' '0.007558969646516145']
#  ['G_P_change' '0.007393388500102516']
#  ['F_A_change' '0.00728656825490126']
#  ['S_G_change' '0.007226545038694576']
#  ['F_M_change' '0.0072155602647103745']
#  ['P_Q_change' '0.007163619510622166']
#  ['A_G_change' '0.0070995423653512635']
#  ['F_D_change' '0.0070961610708064615']
#  ['L_D_change' '0.006949599890124558']
#  ['C_W_change' '0.006878989868146723']
#  ['W_P_change' '0.006741731149128238']
#  ['interface_residues_bb_clashing_change' '0.006618706954389264']
#  ['A_S_change' '0.00661668007240257']
#  ['I_M_change' '0.006389180051874943']
#  ['H_N_change' '0.006379929606583401']
#  ['G_H_change' '0.00627927087861746']
#  ['P_M_change' '0.006277168637885744']
#  ['K_C_change' '0.006175638133763428']
#  ['V_E_change' '0.006060141247436146']
#  ['V_Y_change' '0.005962483281565678']
#  ['L_R_change' '0.005894881990042178']
#  ['G_L_change' '0.005862049629717259']
#  ['G_W_change' '0.005707384820773376']
#  ['A_I_change' '0.005686646503081816']
#  ['I_A_change' '0.005671577822444762']
#  ['Y_M_change' '0.005659795871637341']
#  ['F_F_change' '0.005617754544917419']
#  ['Y_C_change' '0.005578174474759612']
#  ['S_T_change' '0.005377400694411616']
#  ['N_C_change' '0.005197520289620394']
#  ['V_K_change' '0.005163874210412089']
#  ['T_S_change' '0.005008436851096976']
#  ['G_Q_change' '0.004893173168026177']
#  ['V_S_change' '0.004772262120552817']
#  ['W_F_change' '0.004699704475534361']
#  ['Q_I_change' '0.004678742519408141']
#  ['D_Q_change' '0.0046762690750059566']
#  ['S_V_change' '0.0046415943683559835']
#  ['C_E_change' '0.004425133950850313']
#  ['Y_K_change' '0.00441384265478062']
#  ['G_E_change' '0.004372491451630545']
#  ['D_C_change' '0.004263211216038343']
#  ['L_F_change' '0.004262225089107563']
#  ['M_S_change' '0.0042591923517316665']
#  ['R_I_change' '0.004204522767679908']
#  ['C_S_change' '0.004187137306817412']
#  ['M_M_change' '0.004027929768637861']
#  ['N_H_change' '0.003978395752850972']
#  ['M_D_change' '0.003926615872482664']
#  ['R_D_change' '0.003904176671167159']
#  ['W_D_change' '0.0038656389282389902']
#  ['V_N_change' '0.0038358061376893016']
#  ['N_L_change' '0.0037708790498027778']
#  ['V_V_change' '0.003756033929793956']
#  ['Y_I_change' '0.003685733794493551']
#  ['C_K_change' '0.0036702190166013615']
#  ['E_Q_change' '0.0036685703418182225']
#  ['I_T_change' '0.0036506094902408748']
#  ['D_H_change' '0.003536069132646924']
#  ['K_E_change' '0.003398267102551644']
#  ['M_F_change' '0.0033924550938140285']
#  ['L_K_change' '0.003327612442916683']
#  ['N_N_change' '0.003219016209687675']
#  ['M_R_change' '0.003164201874963579']
#  ['H_V_change' '0.0031232040960200713']
#  ['M_I_change' '0.00310574514986639']
#  ['I_P_change' '0.003099147494759258']
#  ['W_R_change' '0.002902843669035704']
#  ['A_E_change' '0.0027949416510582026']
#  ['I_I_change' '0.002782507715631155']
#  ['E_G_change' '0.0027620321120604974']
#  ['P_R_change' '0.0027476433260267275']
#  ['W_N_change' '0.0027042059543986863']
#  ['S_N_change' '0.0026412639769726187']
#  ['C_C_change' '0.0026311749315022226']
#  ['Q_D_change' '0.002619595152190124']
#  ['A_F_change' '0.0024298847715213956']
#  ['R_R_change' '0.0024105644708678486']
#  ['sloop_entropy_change' '0.0021424339502997825']
#  ['S_A_change' '0.0021205131093935403']
#  ['interface_residues_vdw_clashing_change' '0.002118654115636831']
#  ['S_I_change' '0.0020843810840442956']
#  ['T_I_change' '0.0020614252071333716']
#  ['N_S_change' '0.00205527124999505']
#  ['R_S_change' '0.0020380582306522843']
#  ['V_H_change' '0.0019495240916027612']
#  ['I_F_change' '0.0018636835019503195']
#  ['G_V_change' '0.001732197009217007']
#  ['P_A_change' '0.0016781779110202066']
#  ['L_W_change' '0.001657128656417317']
#  ['M_Y_change' '0.001634019548593102']
#  ['R_L_change' '0.0016012019127000787']
#  ['C_Q_change' '0.0015575646797403309']
#  ['Q_Y_change' '0.0015370692814724585']
#  ['V_I_change' '0.0015154285523057975']
#  ['A_H_change' '0.0014880542298403299']
#  ['V_C_change' '0.0014748271856936945']
#  ['R_W_change' '0.001459189134427108']
#  ['K_T_change' '0.0014434732211738854']
#  ['T_L_change' '0.0014401052205899045']
#  ['L_P_change' '0.0013684209329745123']
#  ['C_D_change' '0.0011706849162362865']
#  ['M_P_change' '0.001123121458258991']
#  ['H_M_change' '0.0010567857030761019']
#  ['H_Q_change' '0.0010491562078760452']
#  ['Q_M_change' '0.0010050853487177935']
#  ['P_L_change' '0.0008817110302439257']
#  ['G_M_change' '0.0007940345945696148']
#  ['C_H_change' '0.0007830947257647658']
#  ['I_Q_change' '0.0007293954404326009']
#  ['V_P_change' '0.0006661063450570381']
#  ['Q_E_change' '0.0006166392053739145']
#  ['E_T_change' '0.0006002129112481214']
#  ['T_Q_change' '0.0005469171219769642']
#  ['P_G_change' '0.0005202890239921487']
#  ['Y_F_change' '0.00044432395368443345']
#  ['V_A_change' '0.0004178596883861463']
#  ['A_D_change' '0.00039788355772074624']
#  ['D_M_change' '0.00025924282216527317']
#  ['F_V_change' '0.00025010860625385156']
#  ['E_C_change' '0.00023359294405222997']
#  ['P_W_change' '0.00021672254201332564']
#  ['Q_S_change' '0.00021453372034074825']
#  ['N_Q_change' '0.00019912151917278464']
#  ['H_P_change' '0.00010181512192763975']
#  ['A_M_change' '1.091989932588966e-05']
#  ['A_A_change' '0.0']
#  ['A_K_change' '0.0']
#  ['A_L_change' '0.0']
#  ['A_P_change' '0.0']
#  ['A_V_change' '0.0']
#  ['A_W_change' '0.0']
#  ['C_A_change' '0.0']
#  ['C_G_change' '0.0']
#  ['C_L_change' '0.0']
#  ['C_M_change' '0.0']
#  ['C_N_change' '0.0']
#  ['C_T_change' '0.0']
#  ['C_V_change' '0.0']
#  ['D_A_change' '0.0']
#  ['D_E_change' '0.0']
#  ['D_G_change' '0.0']
#  ['D_I_change' '0.0']
#  ['D_K_change' '0.0']
#  ['D_P_change' '0.0']
#  ['D_R_change' '0.0']
#  ['D_T_change' '0.0']
#  ['D_V_change' '0.0']
#  ['D_W_change' '0.0']
#  ['E_A_change' '0.0']
#  ['E_D_change' '0.0']
#  ['E_F_change' '0.0']
#  ['E_I_change' '0.0']
#  ['E_K_change' '0.0']
#  ['E_M_change' '0.0']
#  ['E_P_change' '0.0']
#  ['E_R_change' '0.0']
#  ['E_S_change' '0.0']
#  ['E_V_change' '0.0']
#  ['E_W_change' '0.0']
#  ['E_Y_change' '0.0']
#  ['F_C_change' '0.0']
#  ['F_E_change' '0.0']
#  ['F_G_change' '0.0']
#  ['F_H_change' '0.0']
#  ['F_I_change' '0.0']
#  ['F_K_change' '0.0']
#  ['F_L_change' '0.0']
#  ['F_S_change' '0.0']
#  ['F_W_change' '0.0']
#  ['F_Y_change' '0.0']
#  ['G_A_change' '0.0']
#  ['G_C_change' '0.0']
#  ['G_D_change' '0.0']
#  ['G_F_change' '0.0']
#  ['G_G_change' '0.0']
#  ['G_R_change' '0.0']
#  ['G_T_change' '0.0']
#  ['H_C_change' '0.0']
#  ['H_G_change' '0.0']
#  ['H_H_change' '0.0']
#  ['H_I_change' '0.0']
#  ['H_K_change' '0.0']
#  ['H_L_change' '0.0']
#  ['H_S_change' '0.0']
#  ['H_T_change' '0.0']
#  ['H_W_change' '0.0']
#  ['H_Y_change' '0.0']
#  ['I_C_change' '0.0']
#  ['I_D_change' '0.0']
#  ['I_E_change' '0.0']
#  ['I_G_change' '0.0']
#  ['I_H_change' '0.0']
#  ['I_K_change' '0.0']
#  ['I_L_change' '0.0']
#  ['I_N_change' '0.0']
#  ['I_S_change' '0.0']
#  ['I_V_change' '0.0']
#  ['I_W_change' '0.0']
#  ['I_Y_change' '0.0']
#  ['K_H_change' '0.0']
#  ['K_K_change' '0.0']
#  ['K_L_change' '0.0']
#  ['K_N_change' '0.0']
#  ['K_P_change' '0.0']
#  ['K_R_change' '0.0']
#  ['K_S_change' '0.0']
#  ['K_Y_change' '0.0']
#  ['L_A_change' '0.0']
#  ['L_C_change' '0.0']
#  ['L_H_change' '0.0']
#  ['L_I_change' '0.0']
#  ['L_L_change' '0.0']
#  ['L_Q_change' '0.0']
#  ['L_S_change' '0.0']
#  ['L_T_change' '0.0']
#  ['L_V_change' '0.0']
#  ['L_Y_change' '0.0']
#  ['M_A_change' '0.0']
#  ['M_C_change' '0.0']
#  ['M_G_change' '0.0']
#  ['M_H_change' '0.0']
#  ['M_K_change' '0.0']
#  ['M_L_change' '0.0']
#  ['M_N_change' '0.0']
#  ['M_Q_change' '0.0']
#  ['M_T_change' '0.0']
#  ['M_V_change' '0.0']
#  ['N_A_change' '0.0']
#  ['N_F_change' '0.0']
#  ['N_G_change' '0.0']
#  ['N_I_change' '0.0']
#  ['N_K_change' '0.0']
#  ['N_M_change' '0.0']
#  ['N_P_change' '0.0']
#  ['N_T_change' '0.0']
#  ['N_V_change' '0.0']
#  ['N_W_change' '0.0']
#  ['P_C_change' '0.0']
#  ['P_D_change' '0.0']
#  ['P_E_change' '0.0']
#  ['P_F_change' '0.0']
#  ['P_H_change' '0.0']
#  ['P_K_change' '0.0']
#  ['P_N_change' '0.0']
#  ['P_P_change' '0.0']
#  ['P_T_change' '0.0']
#  ['P_V_change' '0.0']
#  ['Q_A_change' '0.0']
#  ['Q_C_change' '0.0']
#  ['Q_F_change' '0.0']
#  ['Q_G_change' '0.0']
#  ['Q_H_change' '0.0']
#  ['Q_K_change' '0.0']
#  ['Q_L_change' '0.0']
#  ['Q_N_change' '0.0']
#  ['Q_P_change' '0.0']
#  ['Q_T_change' '0.0']
#  ['Q_V_change' '0.0']
#  ['Q_W_change' '0.0']
#  ['R_C_change' '0.0']
#  ['R_F_change' '0.0']
#  ['R_H_change' '0.0']
#  ['R_K_change' '0.0']
#  ['R_M_change' '0.0']
#  ['R_T_change' '0.0']
#  ['R_V_change' '0.0']
#  ['S_C_change' '0.0']
#  ['S_D_change' '0.0']
#  ['S_H_change' '0.0']
#  ['S_L_change' '0.0']
#  ['S_M_change' '0.0']
#  ['S_P_change' '0.0']
#  ['S_W_change' '0.0']
#  ['T_A_change' '0.0']
#  ['T_C_change' '0.0']
#  ['T_D_change' '0.0']
#  ['T_F_change' '0.0']
#  ['T_G_change' '0.0']
#  ['T_H_change' '0.0']
#  ['T_K_change' '0.0']
#  ['T_N_change' '0.0']
#  ['T_P_change' '0.0']
#  ['T_R_change' '0.0']
#  ['T_T_change' '0.0']
#  ['T_V_change' '0.0']
#  ['T_Y_change' '0.0']
#  ['V_D_change' '0.0']
#  ['V_F_change' '0.0']
#  ['V_L_change' '0.0']
#  ['V_M_change' '0.0']
#  ['V_R_change' '0.0']
#  ['V_W_change' '0.0']
#  ['W_A_change' '0.0']
#  ['W_C_change' '0.0']
#  ['W_E_change' '0.0']
#  ['W_G_change' '0.0']
#  ['W_H_change' '0.0']
#  ['W_I_change' '0.0']
#  ['W_L_change' '0.0']
#  ['W_M_change' '0.0']
#  ['W_Q_change' '0.0']
#  ['W_S_change' '0.0']
#  ['W_V_change' '0.0']
#  ['W_W_change' '0.0']
#  ['Y_E_change' '0.0']
#  ['Y_G_change' '0.0']
#  ['Y_Q_change' '0.0']
#  ['Y_V_change' '0.0']
#  ['entropy_mainchain_change' '0.0']
#  ['mloop_entropy_change' '0.0']
#  ['water_bridge_change' '0.0']
#  ['disulfide_change' '0.0']
#  ['electrostatic_kon_change' '0.0']
#  ['partial_covalent_bonds_change' '0.0']
#  ['entropy_complex_change' '0.0']
#  ['sloop_entropy_wt' '0.0']
#  ['mloop_entropy_wt' '0.0']
#  ['water_bridge_wt' '0.0']
#  ['entropy_complex_wt' '0.0']
#  ['interface_residues_vdw_clashing_wt' '0.0']]

# %%
included_features = np.array(sorted_scores)[:,0][:30]

# %%
X_train_2 = X_train[included_features]
y_train_2 =  y_train[X_train_2.index]

X_test_2 = X_test[included_features]
y_test_2 =  y_test[X_test_2.index]
#new_model = grid1.fit

# %%
model2 = grid1.fit(X_train_2,y_train_2)
# Out:
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  50 | elapsed:    2.0s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  41 out of  50 | elapsed:    2.8s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    3.4s finished

# %%
# index of best scores
rmse_bestCV_test_index = model2.cv_results_['mean_test_neg_mean_squared_error'].argmax()
rmse_bestCV_train_index = model2.cv_results_['mean_train_neg_mean_squared_error'].argmax()
r2_bestCV_test_index = model2.cv_results_['mean_test_r2'].argmax()
r2_bestCV_train_index = model2.cv_results_['mean_train_r2'].argmax()
# scores
rmse_bestCV_test_score = model2.cv_results_['mean_test_neg_mean_squared_error'][rmse_bestCV_test_index]
rmse_bestCV_test_std = model2.cv_results_['std_test_neg_mean_squared_error'][rmse_bestCV_test_index]
rmse_bestCV_train_score = model2.cv_results_['mean_train_neg_mean_squared_error'][rmse_bestCV_train_index]
rmse_bestCV_train_std = model2.cv_results_['std_train_neg_mean_squared_error'][rmse_bestCV_train_index]

r2_bestCV_test_score = model2.cv_results_['mean_test_r2'][r2_bestCV_test_index]
r2_bestCV_test_std = model2.cv_results_['std_test_r2'][r2_bestCV_test_index]
r2_bestCV_train_score = model2.cv_results_['mean_train_r2'][r2_bestCV_train_index]
r2_bestCV_train_std = model2.cv_results_['std_train_r2'][r2_bestCV_train_index]

print('CV test RMSE {:f} +/- {:f}'.format(np.sqrt(-rmse_bestCV_test_score),np.sqrt(rmse_bestCV_test_std)))
print('CV train RMSE {:f} +/- {:f}'.format(np.sqrt(-rmse_bestCV_train_score),np.sqrt(rmse_bestCV_train_std)))
print('CV test r2 {:f} +/- {:f}'.format(r2_bestCV_test_score,r2_bestCV_test_std))
print('CV train r2 {:f} +/- {:f}'.format(r2_bestCV_train_score,r2_bestCV_train_std))

print(r2_bestCV_train_score-r2_bestCV_test_score)
print("",model2.best_params_)
y_test_pred = model2.best_estimator_.predict(X_test_2)
y_train_pred = model2.best_estimator_.predict(X_train_2)
print("\nRMSE for test dataset: {}".format(np.round(np.sqrt(mean_squared_error(y_test_2, y_test_pred)), 2)))
print("RMSE for train dataset: {}".format(np.round(np.sqrt(mean_squared_error(y_train_2, y_train_pred)), 2)))
print("pearson corr  {:f}".format(np.corrcoef(y_test_pred,y_test_2)[0][1]))
print('R2 test',r2_score(y_test_2,y_test_pred))
print('R2 train',r2_score(y_train_2,y_train_pred))
# Out:
# CV test RMSE 0.719772 +/- 0.263385
# CV train RMSE 0.582542 +/- 0.105783
# CV test r2 0.216511 +/- 0.037537
# CV train r2 0.488137 +/- 0.008156
# 0.2716264495165316
#  {'randomforestregressor__bootstrap': True, 'randomforestregressor__max_depth': 20, 'randomforestregressor__max_features': 'sqrt', 'randomforestregressor__max_leaf_nodes': None, 'randomforestregressor__min_samples_leaf': 9, 'randomforestregressor__min_samples_split': 10, 'randomforestregressor__n_estimators': 150, 'randomforestregressor__random_state': 1212, 'variancethreshold__threshold': 0.0}
#
# RMSE for test dataset: 0.74
# RMSE for train dataset: 0.57
# pearson corr  0.571382
# R2 test 0.272262904482078
# R2 train 0.5039222672537371
