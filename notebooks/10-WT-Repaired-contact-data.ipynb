# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import pickle
import sys

ABPRED_DIR = Path.cwd().parent
if ABPRED_DIR not in sys.path:
    sys.path.append(str(ABPRED_DIR))
    
from AbPred.interface_contacts import InterfaceContacts

# %%
# Paths
DATA = ABPRED_DIR / "data"
PDBS_DIR = Path("pdbsWT_to_repair/")

# Dataframes 
DF_features = pd.read_csv(DATA / "DF_wildtype_features.csv",index_col=0)
ab_bind_mCSM_HM = pd.read_csv(DATA / "ab_bind_mCSM_HM.csv",index_col=0)

# %%
#Funcion para el sorting de paths por numero
def extract_num(pdb):
    return int(pdb.split(".")[2])

def sort_df(df, column_idx, key):
    '''Takes dataframe, column index and custom function for sorting, 
    returns dataframe sorted by this column using this function'''
    
    col = df.ix[:,column_idx]
    temp = np.array(col.values.tolist())
    order = sorted(range(len(temp)), key=lambda j: key(temp[j]))
    return df.ix[order]

# Reset index and sorting for posterior merge data
DF_features_index = DF_features.reset_index()
DF_features_index_sorted = sort_df(DF_features_index,0,extract_num)
DF_features_index_sorted.set_index("index",inplace=True)
# Out:
# /Users/vfica/miniconda3/envs/bio/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':
# /Users/vfica/miniconda3/envs/bio/lib/python3.6/site-packages/ipykernel_launcher.py:12: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if sys.path[0] == '':

# %%
repair_clean_pdbs = list(PDBS_DIR.glob("*Repair.clean.pdb"))
ind_pdb_problem = [int(ind.name.split(".")[2]) for ind in repair_clean_pdbs]
partner_pdb_problem = ab_bind_mCSM_HM.iloc[ind_pdb_problem]["Partners(A_B)"]

# %% [markdown]
# # Reanalisis con arpegio de estructuras problemas optimizadas con Foldx.

# %%
# Partner of pdbs with interface problem
for pdb,partner_pdbs in zip(repair_clean_pdbs,partner_pdb_problem):
    
    ic = InterfaceContacts(pdb)
    print("Running arpeggio")
    ic.run_arpeggio()
    ic.get_ic(partners=partner_pdbs)
    print("Finish getting interface contact\n")
    ic.get_pymol_contacts()
    print("END")
# Out:
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1AK4.mut.6.H487A_Repair.clean.pml
# Drew 324 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1BJ1.mut.21.H86A_Repair.clean.pml
# Drew 770 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1BJ1.mut.22.H90A_Repair.clean.pml
# Drew 746 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1BJ1.mut.26.K48A_Repair.clean.pml
# Drew 768 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1BJ1.mut.31.Q87A_Repair.clean.pml
# Drew 772 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1BJ1.mut.32.Q89A_Repair.clean.pml
# Drew 763 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1CZ8.mut.40.H86A_Repair.clean.pml
# Drew 899 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1CZ8.mut.41.H90A_Repair.clean.pml
# Drew 891 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1CZ8.mut.45.K48A_Repair.clean.pml
# Drew 900 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1CZ8.mut.50.Q87A_Repair.clean.pml
# Drew 893 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1CZ8.mut.51.Q89A_Repair.clean.pml
# Drew 847 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1DQJ.mut.59.R21A_Repair.clean.pml
# Drew 489 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1DQJ.mut.69.Y53A_Repair.clean.pml
# Drew 533 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1DVF.mut.100.Y102A_Repair.clean.pml
# Drew 476 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1DVF.mut.89.W52A_Repair.clean.pml
# Drew 526 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1DVF.mut.99.R106A_Repair.clean.pml
# Drew 496 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1JTG.mut.116.D49A_Repair.clean.pml
# Drew 684 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1N8Z.mut.234.Y56A_Repair.clean.pml
# Drew 394 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1N8Z.mut.237.H91A_Repair.clean.pml
# Drew 426 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 1VFB.mut.277.W52A_Repair.clean.pml
# Drew 415 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 2NYY.mut.343.E920A_Repair.clean.pml
# Drew 639 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 2NYY.mut.344.F917A_Repair.clean.pml
# Drew 674 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 2NYY.mut.345.F953A_Repair.clean.pml
# Drew 688 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 2NYY.mut.353.N954A_Repair.clean.pml
# Drew 677 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 2NYY.mut.363.Y31Q_Repair.clean.pml
# Drew 680 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 2NZ9.mut.372.F917A_Repair.clean.pml
# Drew 669 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 2NZ9.mut.373.F953A_Repair.clean.pml
# Drew 676 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 2NZ9.mut.381.N954A_Repair.clean.pml
# Drew 663 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 3BDY.mut.418.W50A_Repair.clean.pml
# Drew 518 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 3BE1.mut.438.Y56A_Repair.clean.pml
# Drew 383 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 3BE1.mut.442.H91A_Repair.clean.pml
# Drew 362 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 3BE1.mut.446.R27DA_Repair.clean.pml
# Drew 379 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 3BN9.mut.471.Q174A_Repair.clean.pml
# Drew 710 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 3BN9.mut.484.Q100AV_Repair.clean.pml
# Drew 709 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 3BN9.mut.490.Y99S_Repair.clean.pml
# Drew 740 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 3HFM.mut.511.R21A_Repair.clean.pml
# Drew 481 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 3K2M.mut.517.Y35A_Repair.clean.pml
# Drew 399 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file 3K2M.mut.519.Y87A_Repair.clean.pml
# Drew 423 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.596.D1062A_Repair.clean.pml
# Drew 676 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.597.D902A_Repair.clean.pml
# Drew 640 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.598.E920A_Repair.clean.pml
# Drew 620 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.599.F953A_Repair.clean.pml
# Drew 671 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.600.I917A_Repair.clean.pml
# Drew 618 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.601.K915A_Repair.clean.pml
# Drew 701 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.602.K955A_Repair.clean.pml
# Drew 688 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.603.L919A_Repair.clean.pml
# Drew 629 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.604.N918A_Repair.clean.pml
# Drew 640 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.605.N957A_Repair.clean.pml
# Drew 687 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.606.P1063A_Repair.clean.pml
# Drew 658 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.607.R1061A_Repair.clean.pml
# Drew 685 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.608.R1064A_Repair.clean.pml
# Drew 656 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.609.R903A_Repair.clean.pml
# Drew 656 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.610.S954A_Repair.clean.pml
# Drew 636 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.611.T923A_Repair.clean.pml
# Drew 699 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.612.K30R_Repair.clean.pml
# Drew 680 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.613.M34Q_Repair.clean.pml
# Drew 701 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.614.Y31D_Repair.clean.pml
# Drew 618 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.615.Y31Q_Repair.clean.pml
# Drew 666 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.616.Y57Q_Repair.clean.pml
# Drew 682 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.617.D30Y_Repair.clean.pml
# Drew 665 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.618.H34R_Repair.clean.pml
# Drew 671 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.619.S28Q_Repair.clean.pml
# Drew 687 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NYY.mut.620.S31N_Repair.clean.pml
# Drew 678 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.621.D1062A_Repair.clean.pml
# Drew 642 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.622.D902A_Repair.clean.pml
# Drew 632 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.623.E920A_Repair.clean.pml
# Drew 624 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.624.F953A_Repair.clean.pml
# Drew 644 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.625.I917A_Repair.clean.pml
# Drew 628 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.626.K915A_Repair.clean.pml
# Drew 639 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.627.K955A_Repair.clean.pml
# Drew 644 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.628.L919A_Repair.clean.pml
# Drew 641 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.629.N918A_Repair.clean.pml
# Drew 644 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.630.N957A_Repair.clean.pml
# Drew 646 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.631.P1063A_Repair.clean.pml
# Drew 638 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.632.R1061A_Repair.clean.pml
# Drew 660 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.633.R1064A_Repair.clean.pml
# Drew 654 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.634.R903A_Repair.clean.pml
# Drew 624 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.635.S954A_Repair.clean.pml
# Drew 643 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_2NZ9.mut.636.T923A_Repair.clean.pml
# Drew 642 total contacts.
# END
# Running arpeggio
# Getting only interface contacts
# Finish getting interface contact
#
# Creating file HM_3BN9.mut.638.Q100AV_Repair.clean.pml
# Drew 622 total contacts.
# END

# %% [markdown]
# # Creando dataframe final de estructuras mutadas (originales de Ab-bind y mCSM)

# %%
interface_sifts = []
pdbs_names = []
for paths in PDBS_DIR.glob("*.interface_contacts"):
    name = paths.name[:-19]
    contact_data = pd.read_table(paths)
    interface_sift_sum = contact_data.drop(["atom_bgn","atom_end","interacting_entities"],axis=1).sum()
    
    interface_sifts.append(interface_sift_sum.values)
    pdbs_names.append(name)

# %%
col_names = contact_data.drop(["atom_bgn","atom_end","interacting_entities"],axis=1).columns
DF_features_repaired = pd.DataFrame(interface_sifts,columns=col_names,index=pdbs_names)
DF_features_repaired.to_csv(DATA / "DF_wildtype_repared.csv")
DF_features_repaired.head()
# Out:
#                                clash  covalent  vdw_clash  vdw  proximal  \
# 1AK4.mut.6.H487A_Repair.clean      0         0          9    5       310
# 1BJ1.mut.21.H86A_Repair.clean      0         0         16    8       746
# 1BJ1.mut.22.H90A_Repair.clean      0         0         16    4       726
# 1BJ1.mut.26.K48A_Repair.clean      0         2         24   10       732
# 1BJ1.mut.31.Q87A_Repair.clean      0         0         21   10       741
#
#                                hbond  weak_hbond  xbond  ionic  metal_complex  \
# 1AK4.mut.6.H487A_Repair.clean      7           4      0      0              0
# 1BJ1.mut.21.H86A_Repair.clean     11          10      0      0              0
# 1BJ1.mut.22.H90A_Repair.clean     11          10      0      0              0
# 1BJ1.mut.26.K48A_Repair.clean     11          11      0      0              0
# 1BJ1.mut.31.Q87A_Repair.clean     11          10      0      0              0
#
#                                aromatic  hydrophobic  carbonyl  polar  \
# 1AK4.mut.6.H487A_Repair.clean         0           31         0      7
# 1BJ1.mut.21.H86A_Repair.clean        15           25         1     12
# 1BJ1.mut.22.H90A_Repair.clean         9           29         1     12
# 1BJ1.mut.26.K48A_Repair.clean        15           26         1     13
# 1BJ1.mut.31.Q87A_Repair.clean        17           30         1     12
#
#                                weak_polar
# 1AK4.mut.6.H487A_Repair.clean           3
# 1BJ1.mut.21.H86A_Repair.clean          11
# 1BJ1.mut.22.H90A_Repair.clean          10
# 1BJ1.mut.26.K48A_Repair.clean          13
# 1BJ1.mut.31.Q87A_Repair.clean          13

# %%
# load pickle with name of pdbs with interface problems

in_pickle = open("pdbsWT_to_repair.pkl","rb")
pdbs_with_problem = pickle.load(in_pickle)
pdb_names_problems = [names.split("/")[-1][:-4] for names in pdbs_with_problem]

# %%
DF_drop_pdbs = DF_features_index_sorted[~DF_features_index_sorted.index.isin(pdb_names_problems)]

# %%
#concatenar entrmedio para preservar orden 
DF_final_wildtype = pd.concat([DF_drop_pdbs,DF_features_repaired])

# %%
DF_final_wildtype_resetindex =DF_final_wildtype.reset_index()

# %%
DF_final_wildtype_resetindex_sorted = sort_df(DF_final_wildtype_resetindex,0,extract_num)
DF_final_wildtype_resetindex_sorted.set_index("index",inplace=True)
# Out:
# /Users/vfica/miniconda3/envs/bio/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':
# /Users/vfica/miniconda3/envs/bio/lib/python3.6/site-packages/ipykernel_launcher.py:12: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if sys.path[0] == '':

# %%
# Los signos de ddG fueron mantenidos .
DF_final_wildtype_resetindex_sorted["ddG(kcal/mol)"] = ab_bind_mCSM_HM["ddG(kcal/mol)"].values

# %%
DF_final_wildtype_resetindex_sorted.to_csv(DATA/"DF_wildtype_features_final.csv")

# %% [markdown]
# # Dataframe final

# %%
DF_mutated_features_final=pd.read_csv(DATA/"DF_mutated_features_final.csv",index_col=0)

# %%
DF_sabpred_final = pd.concat([DF_final_wildtype_resetindex_sorted,DF_mutated_features_final])

# %%
DF_sabpred_final.to_csv(DATA/"DF_AbPred_final.csv")
